# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_csv('trending.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15923 entries, 0 to 15922
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publish_time       15923 non-null  object
#  1   channel_id         15923 non-null  object
#  2   title              15923 non-null  object
#  3   description        15615 non-null  object
#  4   thumbnail_url      0 non-null      float64
#  5   thumbnail_width    0 non-null      float64
#  6   thumbnail_height   0 non-null      float64
#  7   channel_name       15923 non-null  object
#  8   tags               14190 non-null  object
#  9   category_id        15923 non-null  int64
#  10  live_status        15923 non-null  object
#  11  local_title        15923 non-null  object
#  12  local_description  15615 non-null  object
#  13  duration           15923 non-null  object
#  14  dimension          15923 non-null  object
#  15  definition         15923 non-null  object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                publish_time                channel_id  \
# 0      2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1      2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2      2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3      2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4      2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
# ...                     ...                       ...
# 15918  2021-06-02T10:53:28Z  UCeHGtIr2IJH1yNMTvea1mzA
# 15919  2021-05-26T17:00:21Z  UCkYTR78_Knz-3S5NTxJfCIw
# 15920  2021-05-29T12:04:58Z  UCVNvQrRxK4FOo6_zjjtdhTw
# 15921  2021-05-31T12:30:13Z  UC6GIiaWJxZyKk_CAVa6y54Q
# 15922  2021-05-26T07:00:13Z  UCo39yGkzqhxQDhCqyXQ8zsA
#
#                                                    title  \
# 0                            aespa 에스파 'Forever (약속)' MV
# 1      [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2         CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# ...

# %%
subsetting the dataset based on publish date

# %% [raw]
# filtered_df = df.loc[(df['publish_time'] >= '2021-02-01') & (df['publish_time'] < '2021-02-28')].tail(5)
# filtered_df

# %%
subsetting the dataset based on trending date

# %%
filtered_df = df.loc[(df['trending_time'] >= '2021-05-01') & (df['trending_time'] < '2021-05-31')].head(5)
filtered_df
# Out:
#                publish_time                channel_id  \
# 11466  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g
# 11467  2021-05-12T10:39:24Z  UCmxAIW7RDDC88EPk4ry16Kg
# 11468  2021-05-13T11:23:42Z  UCER4rvDnRBPr_ncYW4UCZjg
# 11469  2021-05-13T04:29:38Z  UCfx3oPv3cJm2aCJ7UnhKx8A
# 11470  2021-05-14T04:00:16Z  UCCY_8y1FjtOegxKB4s2bWqw
#
#                                                    title  \
# 11466                NCT DREAM 엔시티 드림 '맛 (Hot Sauce)' MV
# 11467  Detik-detik Roket Hamas VS Rudal Pencegat Iron...
# 11468  Detik-detik Kendaraan Israel Meledak Akibat Se...
# 11469                    SUASANA LEBARAN DI KAMPUNG BETI
# 11470  Bella Poarch - Build a B*tch (Official Music V...
#
#                                              description  thumbnail_url  \
# 11466  NCT DREAM's 1st album "Hot Sauce" is out!\nLis...            NaN
# 11467  TRIBUN-VIDEO.COM - Militan Palestina, Hamas, m...            NaN
# 11468  Jakarta, https://www.tvOnenews.com - Puluhan o...            NaN
# ...

# %%
subsetting the dataset based on channels

# %%
channels =["SMTOWN"]
condition = df["channel_name"].isin(channels)
df[condition]
# Out:
#                publish_time                channel_id  \
# 0      2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 18     2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g
# 200    2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 219    2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g
# 402    2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# ...                     ...                       ...
# 15095  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g
# 15197  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g
# 15428  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g
# 15653  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g
# 15877  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g
#
#                                      title  \
# 0              aespa 에스파 'Forever (약속)' MV
# 18      aespa 에스파 'Forever (약속)' MV Teaser
# 200            aespa 에스파 'Forever (약속)' MV
# 219     aespa 에스파 'Forever (약속)' MV Teaser
# 402            aespa 에스파 'Forever (약속)' MV
# ...                                    ...
# ...

# %%
grouping based on channels

# %%
print(df.groupby(["channel_name"])[['publish_time']].count())
# Out:
#                                              publish_time
# channel_name
# #temantapimenikah                                       4
# (G)I-DLE (여자)아이들 (Official YouTube Channel)             9
# 1 vs 9999                                              14
# 10 News First                                          13
# 100kpj com                                              2
# ...                                                   ...
# 최시원 Siwon Choi                                          8
# 키이스트 KEYEAST official                                   3
# 피기보이 PiggyBoy                                           1
# 한밤 HANBAM                                               1
# 혀니콤보 TV                                                 8
#
# [1143 rows x 1 columns]

# %%
grouping based on trending date

# %%
df_parse = pd.read_csv('trending.csv', parse_dates=['trending_time'])
df_parse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15923 entries, 0 to 15922
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publish_time       15923 non-null  object
#  1   channel_id         15923 non-null  object
#  2   title              15923 non-null  object
#  3   description        15615 non-null  object
#  4   thumbnail_url      0 non-null      float64
#  5   thumbnail_width    0 non-null      float64
#  6   thumbnail_height   0 non-null      float64
#  7   channel_name       15923 non-null  object
#  8   tags               14190 non-null  object
#  9   category_id        15923 non-null  int64
#  10  live_status        15923 non-null  object
#  11  local_title        15923 non-null  object
#  12  local_description  15615 non-null  object
#  13  duration           15923 non-null  object
#  14  dimension          15923 non-null  object
#  15  definition         15923 non-null  object
# ...

# %%
df_parse.resample('D', on='trending_time').mean()
# Out:
#                            thumbnail_url  thumbnail_width  thumbnail_height  \
# trending_time
# 2021-02-07 00:00:00+00:00            NaN              NaN               NaN
# 2021-02-08 00:00:00+00:00            NaN              NaN               NaN
# 2021-02-09 00:00:00+00:00            NaN              NaN               NaN
# 2021-02-10 00:00:00+00:00            NaN              NaN               NaN
# 2021-02-11 00:00:00+00:00            NaN              NaN               NaN
# ...                                  ...              ...               ...
# 2021-05-30 00:00:00+00:00            NaN              NaN               NaN
# 2021-05-31 00:00:00+00:00            NaN              NaN               NaN
# 2021-06-01 00:00:00+00:00            NaN              NaN               NaN
# 2021-06-02 00:00:00+00:00            NaN              NaN               NaN
# 2021-06-03 00:00:00+00:00            NaN              NaN               NaN
#
# ...

# %%
number of uniques channels

# %%
print(df.nunique())
# Out:
# publish_time          3652
# channel_id            1142
# title                 3738
# description           3575
# thumbnail_url            0
# thumbnail_width          0
# thumbnail_height         0
# channel_name          1143
# tags                  2654
# category_id             15
# live_status              1
# local_title           3738
# local_description     3575
# duration              1564
# dimension                1
# definition               2
# caption                  2
# license_status           2
# allowed_region          31
# blocked_region          83
# view                 15846
# like                 14056
# dislike               5041
# favorite                 1
# comment               8576
# trending_time        15923
# _id                  15923
# dtype: int64

# %%
print(df.nunique(axis=1))
# Out:
# 0        18
# 1        19
# 2        19
# 3        18
# 4        19
#          ..
# 15918    19
# 15919    19
# 15920    18
# 15921    19
# 15922    19
# Length: 15923, dtype: int64

# %%
print(df['channel_name'].value_counts())
# Out:
# TRANS7 OFFICIAL                165
# Deddy Corbuzier                151
# SMTOWN                         133
# Indonesian Idol                128
# KOMPASTV                       127
#                               ...
# PUBG MOBILE                      1
# New Home Items                   1
# SBS Entertainment                1
# Geraldytan Channel               1
# Free Fire Malaysia Official      1
# Name: channel_name, Length: 1143, dtype: int64

# %%
print(df['tags'].value_counts())
# Out:
# ['123', '123 go', '123go', '123 go gold', '123gogold', '123go!', '123 go!', '123 go! gold', '123go!gold', 'tantangan', 'lelucon', 'trik kehidupan', 'DIY', 'kerajinan', 'proyek DIY', 'bermain peran', 'komedi', 'sketsa', 'humor', 'tertawa', 'sketsa komedi', 'trik', 'kerjakan sendiri', 'seru', 'lucu', 'video lucu', 'sketsa lucu', 'video seru', 'langkah-langkah', 'cara membuat', 'tutorial', 'buatan tangan', 'buatan rumah']                                                                                                                                                         116
# ...
